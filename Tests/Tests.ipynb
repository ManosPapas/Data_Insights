# %% [markdown]
# # Run Tests

# %% [markdown]
# ### Load Libraries

# %%
# %run "../Libraries/Display.ipynb"
# %run "../Libraries/Standard.ipynb"
# %run "../Libraries/Style.ipynb"
# %run "../Libraries/Modelling.ipynb"
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Load Functions

# %%
# %run "../Tests/Helper.ipynb"
# %run "../Core/Standard.ipynb"
# %run "../Core/Engineering.ipynb"
# %run "../Core/Modelling.ipynb"
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Load Tests

# %%
# %run "../Tests/Core_Standard.ipynb"
# %run "../Tests/Core_Engineering.ipynb"
# %run "../Tests/Core_Modelling.ipynb"
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Run the tests
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_dummy_df (__main__.Test_Engineering) ... ok
# test_fill_na_with_mean (__main__.Test_Engineering) ... ok
# test_fill_na_with_mode (__main__.Test_Engineering) ... ok
# test_fill_na_with_none (__main__.Test_Engineering) ... ok
# test_fill_na_with_zero (__main__.Test_Engineering) ... ok
# test_replace_values (__main__.Test_Engineering) ... ok
# test_caluclate_cumsum (__main__.Test_Modelling) ... ok
# test_plot_pca (__main__.Test_Modelling) ...
# ok
# test_plot_pca_variance (__main__.Test_Modelling) ...
# ok
# test_data_types (__main__.Test_Standard) ... ok
# test_empty_columns (__main__.Test_Standard) ... ok
# test_correlation_heatmap (__main__.Test_Standard_plots) ... ok
# test_count_plot (__main__.Test_Standard_plots) ...
# The column that you provided is not valid for this operation. Try another one.
# ok
# test_plot_log (__main__.Test_Standard_plots) ... ok
# test_plot_regplot (__main__.Test_Standard_plots) ...
# ValueError: could not convert the values! String or Infinite error! Make sure the values are valid!
# ok
# test_plot_stack (__main__.Test_Standard_plots) ...
# AttributeError: Something went wrong! Try another column.
# ok
#
# ----------------------------------------------------------------------
# Ran 16 tests in 1.578s
#
# OK
